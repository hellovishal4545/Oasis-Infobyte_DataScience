# %% [markdown]
# **Author: Vishal khatik**

# %% [markdown]
# **Domain: Data Science**

# %% [markdown]
# **Organization: Oasis Infobyte**

# %% [markdown]
# **Date: 15/7/24 to 15/8/24**

# %% [markdown]
# **Unemployment analysis with python**

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
df = pd.read_csv('/content/Unemployment_Rate_upto_11_2020.csv')

# %%
df.head(2)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74

# %%
df.size
# Out:
# 2403

# %%
df.shape
# Out:
# (267, 9)

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
df.head(1)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
#
#    longitude  latitude
# 0    15.9129     79.74

# %%
x = df['Region']
y = df[' Estimated Unemployment Rate (%)']

# %%
x
# Out:
# 0      Andhra Pradesh
# 1      Andhra Pradesh
# 2      Andhra Pradesh
# 3      Andhra Pradesh
# 4      Andhra Pradesh
#             ...
# 262       West Bengal
# 263       West Bengal
# 264       West Bengal
# 265       West Bengal
# 266       West Bengal
# Name: Region, Length: 267, dtype: object

# %%
y
# Out:
# 0       5.48
# 1       5.83
# 2       5.79
# 3      20.51
# 4      17.43
#        ...
# 262     7.29
# 263     6.83
# 264    14.87
# 265     9.35
# 266     9.98
# Name:  Estimated Unemployment Rate (%), Length: 267, dtype: float64

# %%
df1 = df.iloc[:,3]

# %%
df1
# Out:
# 0       5.48
# 1       5.83
# 2       5.79
# 3      20.51
# 4      17.43
#        ...
# 262     7.29
# 263     6.83
# 264    14.87
# 265     9.35
# 266     9.98
# Name:  Estimated Unemployment Rate (%), Length: 267, dtype: float64

# %%
sns.countplot(df, x="Region.1",color = 'green')
# Out:
# <Axes: xlabel='Region.1', ylabel='count'>

# %%
sns.pairplot(df)

# %%
g = sns.PairGrid(df)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
sns.kdeplot(data = df,x = ' Estimated Unemployment Rate (%)',shade =True)
plt.title('KDE plot of Unemployment Rate')

plt.subplot(2,2,2)
sns.kdeplot(data = df,x = ' Estimated Employed',shade = True)
plt.title('KDE plot of Employed')

plt.subplot(2,2,3)
sns.kdeplot(data = df,x = ' Estimated Labour Participation Rate (%)',shade = True)
plt.title('KDE plot of Labour Participation Rate')

plt.show()
# Out:
# <ipython-input-22-860d1c2d0423>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = df,x = ' Estimated Unemployment Rate (%)',shade =True)
# <ipython-input-22-860d1c2d0423>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = df,x = ' Estimated Employed',shade = True)
# <ipython-input-22-860d1c2d0423>:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = df,x = ' Estimated Labour Participation Rate (%)',shade = True)

# %%
import plotly.express as px

# %%
fig = px.bar(df, x = 'Region', y = ' Estimated Unemployment Rate (%)', color = 'Region',
             title = 'Unemployment Rate in India',template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig =  px.bar(df,x = 'Region.1',y = ' Estimated Unemployment Rate (%)',color = 'Region',
              title = 'Unemployment Rate in India',template = 'plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df,x = 'Region',y = ' Estimated Unemployment Rate (%)',color = 'Region',
             title = 'Unemployment Rate in India',template = 'plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df,x = 'Region',y = ' Estimated Unemployment Rate (%)',color = 'Region',
                 title = 'Unemployment Rate in India',template = 'plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df,x = 'Region',y = ' Estimated Unemployment Rate (%)',color = 'Region',
                 title = 'Unemployment Rate in India',template = 'plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Region.1'].value_counts().plot(kind = 'pie',autopct = '%0.2f%%')
plt.title('Percentage of each Re')
plt.ylabel('',fontsize = 12,c = 'r')
plt.show()

# %%
sns.kdeplot(df[' Estimated Unemployment Rate (%)'],shade = True , color = "Green")
plt.show()
# Out:
# <ipython-input-30-181b4606ef00>:1: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %%
sns.kdeplot(data = df)
# Out:
# <Axes: ylabel='Density'>

# %%
dt = df.iloc[:,4:6]
sns.heatmap(dt,annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize= (8,5))
sns.heatmap(df[[' Estimated Unemployment Rate (%)',' Estimated Employed',' Estimated Labour Participation Rate (%)']].corr())
# Out:
# <Axes: >

# %%
import plotly.express as px

fig = px.scatter(df, x=' Estimated Employed', y=" Estimated Labour Participation Rate (%)",
                 color = 'Region',size= ' Estimated Unemployment Rate (%)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.jointplot(x = ' Estimated Unemployment Rate (%)',
              y =' Estimated Employed',
              data = df,
              hue = 'Region.1')

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'Region.1',y = ' Estimated Unemployment Rate (%)',data = df,palette = ('Spectral'))
plt.title('Bar plot of Unemployment Rate Vs Region')
plt.show()
# Out:
# <ipython-input-37-943866d3bae5>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
X = df.iloc[:,4:6]
y = df.iloc[:,3]

# %%
X.head(1)
# Out:
#     Estimated Employed   Estimated Labour Participation Rate (%)
# 0             16635535                                     41.02

# %%
y.head(1)
# Out:
# 0    5.48
# Name:  Estimated Unemployment Rate (%), dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (213, 2)
# (54, 2)
# (213,)
# (54,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Example:
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 84.87849877429973
# R-squared: 0.07659555570062615

# %%
plt.scatter(y_test,y_pred)

plt.plot(y_test,y_test,'r')

plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)

# %%
X_train_scaled = pd.DataFrame(X_train, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test, columns=X.columns)

# %%
from sklearn.tree import DecisionTreeRegressor # Changed from DecisionTreeClassifier to DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)

y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import mean_squared_error # Import the appropriate metric for regression
import numpy as np

# ... your existing code ...

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Calculate root mean squared error
print(rmse)
# Out:
# 13.759148808190348

# %% [markdown]
# **Decision Tree**

# %%
input_n = df[[' Estimated Unemployment Rate (%)',' Estimated Employed']]

# %%
target = df[' Estimated Labour Participation Rate (%)']

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model.fit(input_n,target)
# Out:
# DecisionTreeRegressor()

# %%
model.score(input_n,target)
# Out:
# 1.0

# %%
model.predict([[20.51,11336911]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning:
#
# X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
# array([33.1])

# %%
df.loc[3]
# Out:
# Region                                      Andhra Pradesh
#  Date                                           30-04-2020
#  Frequency                                               M
#  Estimated Unemployment Rate (%)                     20.51
#  Estimated Employed                               11336911
#  Estimated Labour Participation Rate (%)              33.1
# Region.1                                             South
# longitude                                          15.9129
# latitude                                             79.74
# Name: 3, dtype: object

# %%
x = df['Region']
y = df[' Estimated Unemployment Rate (%)']

# %%
xx = df.iloc[:,3:5]
yy = df.iloc[:,5]

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(xx)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
plt.scatter(xx[' Estimated Unemployment Rate (%)'],xx[' Estimated Employed'],c=y_predicted,cmap='rainbow')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.ylabel('Estimated Employed')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Region.1'].value_counts()
# Out:
# Region.1
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: count, dtype: int64

# %%
df.head(1)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
#
#    longitude  latitude
# 0    15.9129     79.74

# %%
v = df.iloc[:,3:5].values
KM = KMeans(n_clusters=3)
y_means = KM.fit_predict(v)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
plt.scatter(v[:,0],v[:,1],c=y_means,cmap='rainbow')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.ylabel('Estimated Employed')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
